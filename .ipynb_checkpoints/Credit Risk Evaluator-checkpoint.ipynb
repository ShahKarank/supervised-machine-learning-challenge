# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split

# %%
# Import the data
data = pd.read_csv('Resources/lending_data.csv')
data
# Out:
#        loan_size  interest_rate  borrower_income  debt_to_income  \
# 0        10700.0          7.672            52800        0.431818
# 1         8400.0          6.692            43600        0.311927
# 2         9000.0          6.963            46100        0.349241
# 3        10700.0          7.664            52700        0.430740
# 4        10800.0          7.698            53000        0.433962
# ...          ...            ...              ...             ...
# 77531    19100.0         11.261            86600        0.653580
# 77532    17700.0         10.662            80900        0.629172
# 77533    17600.0         10.595            80300        0.626401
# 77534    16300.0         10.068            75300        0.601594
# 77535    15600.0          9.742            72300        0.585062
#
#        num_of_accounts  derogatory_marks  total_debt  loan_status
# 0                    5                 1       22800            0
# ...

# %%
X = data.drop('loan_status', axis=1)
y = data['loan_status'].values
X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train
# Out:
#        loan_size  interest_rate  borrower_income  debt_to_income  \
# 39051    10200.0          7.479            51000        0.411765
# 425       8900.0          6.915            45700        0.343545
# 57850    10000.0          7.366            49900        0.398798
# 70419     9800.0          7.274            49100        0.389002
# 6356     12000.0          8.213            57900        0.481865
# ...          ...            ...              ...             ...
# 19031    11300.0          7.910            55000        0.454545
# 14321    10200.0          7.473            50900        0.410609
# 19646    11500.0          8.030            56200        0.466192
# 66268     8400.0          6.699            43600        0.311927
# 58894     8400.0          6.702            43700        0.313501
#
#        num_of_accounts  derogatory_marks  total_debt
# 39051                4                 1       21000
# 425                  3                 0       15700
# ...

# %%
# Train a Logistic Regression model print the model score
from sklearn.linear_model import LogisticRegression
cf = LogisticRegression(max_iter=10000,random_state=42)
cf.fit(X_train, y_train)
print(f"Train Score: {cf.score(X_train, y_train)}")
print(f"Test Score: {cf.score(X_test, y_test)}")
# Out:
# Train Score: 0.9920896959691842
# Test Score: 0.9917457697069748

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
crf = RandomForestClassifier(random_state=42, n_estimators=500)
crf.fit(X_train, y_train)
print(f"Train Score: {crf.score(X_train, y_train)}")
print(f"Test Score: {crf.score(X_test, y_test)}")
# Out:
# Train Score: 0.9972313935892144
# Test Score: 0.991642591828312
